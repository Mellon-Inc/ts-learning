# %% [markdown]
# # 時系列解析入門

# %% [markdown]
# # はじめに
# ## 1. 時系列データの基本概念の導入 (45分)
# 1. 時系列データの基本概念<br>
#     - a. 時系列データの定義と特徴<br>
#     - b. 時系列データの用途と重要性<br>
#     - c. 時系列データとその他のデータ形式との違い<br>
# 1. 具体例<br>
#     - a. 気象データ<br>
#     - b. 売上データ<br>
#     - c. 株価データ<br>

# %% [markdown]
# ## 2. 時系列データの前処理 (45分)
# 1. 時系列データを解析するための前処理手法<br>
#     - a. 欠損値の処理<br>
#         - 線形補間法<br>
#         - 移動平均補間法<br>
#         - スプライン補間法<br>
#         - カルマン平滑化補間法<br>
#     - b. 定常性と非定常性<br>
#         - 定常性の確認<br>
#             - ADF検定<br>
#         - 対数変換<br>
#     - c. 時系列データからの特徴抽出<br>
#         - トレンドの抽出<br>
#         - 季節性の抽出<br>
#             - FFTによる検出<br>
#         - 残差の抽出<br>
#         - 可視化による定常性の確認
#         - API statsmodelsを利用<br>
#     - d. 時系列データの平滑化<br>
#         - 階差による平滑化<br>
#         - 移動平均による平滑化
#             - 移動平均とは
#             - 単純移動平均（SMA）
#             - 指数移動平均（EMA）
#     - まとめ

# %% [markdown]
# ## 3. 時系列データの可視化 (45分)
# 1. 時系列データの視覚的理解<br>
#     - a. 時系列データの可視化手法<br>
#          - 時系列プロット
#          - 自己相関プロット
#             - 自己相関
#             - 偏自己相関
#          - ラグプロット
#
#     - b. トレンドと季節性のプロット<br>
#         - トレンドの可視化
#             - 移動平均
#         - 季節性の可視化
#             - ボックスプロット
#             - 自己相関プロット（Autocorrelation）
#         - 時系列データの分解（seasonal_decompose）
#         - まとめ

# %% [markdown]
# ## 4. 時系列解析の基礎モデル (60分)
# 1. AR（自己回帰モデル）<br>
# 1. MA（移動平均モデル）<br>
# 1. ARMA（自己回帰移動平均モデル）<br>
# 1. ARIMA（自己回帰差分移動平均モデル）<br>

# %% [markdown]
# ## 5. モデルの評価とチューニング (45分)
# 1. AIC、BIC、RMSEなどの指標の理解
#     - AIC
#     - BIC
#     - RMSE
#     - MAPE
#     - MAE
#     - MSE
# 1. モデルの適合度と過学習のバランス
#     - 適合度と過学習の理解
#     - 適合度と過学習のバランスを取る方法
# 1. モデルのチューニング（パラメータ調整）
#     - ARMAでのチューニング例
#     - ARIMAでのチューニング例

# %% [markdown]
# ## 6. 応用編：多変量時系列モデルと長期予測への応用 (60分)
# 1. VAR（ベクトル自己回帰モデル）
# 1. Prophet
#     - チューニングなしの場合
#     - チューニングありの場合
# 1. SARIMA（季節性ARIMA）
# 1. 状態空間モデル（Linear Dynamical System）
# 1. モデルの特徴まとめ

# %% [markdown]
# ## 7. モデリングの応用と実装の際の注意点 (60分)
# 1. モデルの選択と実装の際の注意点<br>
#     - 時系列解析の2つのアプローチ
#         - 内生変数の動きに着目した予測をする方法
#         - 外生変数を取り込み予測する方法
#     - モデルの解釈性
#         - 解釈性が高いモデル
#         - 解釈性が低いモデル
#     - モデルの使い分け
#
# 2. 実データによる事例
#     - テーブルデータ系の予測モデル事例：交通予測
#         - チューニングなしの場合
#         - チューニングありの場合
#     - 内生変数の動きに着目した予測モデル事例：気象予測
#         - チューニングなしの場合
#         - チューニングありの場合

# %% [markdown]
# ## 8. 質疑応答＆まとめ (30分)
# 1. 実践での課題と今後のステップ
